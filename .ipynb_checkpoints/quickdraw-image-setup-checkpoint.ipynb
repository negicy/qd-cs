# %%
# !pip3 install quickdraw
# Out:
# Collecting quickdraw
#   Using cached quickdraw-0.1.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in c:\users\81901\anaconda3\envs\env1\lib\site-packages (from quickdraw) (2.25.1)
# Requirement already satisfied: pillow in c:\users\81901\anaconda3\envs\env1\lib\site-packages (from quickdraw) (8.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\81901\anaconda3\envs\env1\lib\site-packages (from requests->quickdraw) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\81901\anaconda3\envs\env1\lib\site-packages (from requests->quickdraw) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\81901\anaconda3\envs\env1\lib\site-packages (from requests->quickdraw) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\81901\anaconda3\envs\env1\lib\site-packages (from requests->quickdraw) (2.10)
# Installing collected packages: quickdraw
# Successfully installed quickdraw-0.1.0

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\81901\\presemi/anvis')

# %%
from quickdraw import QuickDrawData

qd = QuickDrawData()
for num in range(10):
    anvil = qd.get_drawing("anvil")
    anvil.image.save(str(anvil.key_id) +".png")
# Out:
# loading anvil drawings
# load complete

# %%
from quickdraw import QuickDrawDataGroup

qdg = QuickDrawDataGroup("anvil", cache_dir="C:\Users\81901\presemi\anvis")
print(qdg.drawing_count)
print(qdg.get_drawing())
# Out:
#   File "<ipython-input-9-bc1f3ecf818a>", line 3
#     qdg = QuickDrawDataGroup("anvil", cache_dir="C:\Users\81901\presemi\anvis")
#                                                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os
from quickdraw import QuickDrawData
from quickdraw import QuickDrawDataGroup
object_name = 'flower'
os.getcwd()
os.chdir('C:\\Users\\81901\\presemi/' + object_name)

object_group = QuickDrawDataGroup(object_name, max_drawings=None)
# qd = QuickDrawData()

for num in range(100):
    img = object_group.get_drawing()
    img.image.save(str(img.key_id) +".png")
# Out:
# downloading flower from https://storage.googleapis.com/quickdraw_dataset/full/binary/flower.bin
# download complete
# loading flower drawings
# load complete

# %%
path='C:\\Users\\81901\\presemi/triangle'
data_list = os.listdir(path)
print(len(data_list))
# Out:
# 100

# %%
# 生成したurlを格納する配列
url_list = []

# %%
# 画像ファイル名からurlを作成
obj_list = ['hat', 'triangle', 'flower']


for obj in obj_list:
    path='C:\\Users\\81901\\presemi/' + obj
    data_list = os.listdir(path)
    
    # 生成したurlのリスト
    #  print(len(url_list))

    for file in data_list:
        # print(file)
        parent_path = "https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/" + obj + '/'
        url = parent_path + file
        #  print(url)
        url_row = [url]
        url_list.append(url_row)
        # print(url_row)
print(len(url_list))
# Out:
# 300

# %%
# 生成したurlをcsvファイルに書き込み
import csv
# print(url_list)
os.getcwd()
os.chdir('C:\\Users\\81901\\presemi/')

with open('image_url_sandbox.csv', 'w') as fout:
    csvout=csv.writer(fout, lineterminator='\n')
    csvout.writerows(url_list)

# %%
print(url_list)
# Out:
# ['https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/.quickdrawcache', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4509443779723264.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4515131285307392.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4543013307023360.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4549326506295296.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4560043863179264.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4593348247552000.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4596584987754496.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4605882769866752.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4635136681312256.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4663611072970752.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4687361755578368.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4695441310482432.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4702024220278784.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4729990513950720.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4736002931294208.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4737979153121280.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4784560191569920.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4788462920138752.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4795410247843840.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4796900505026560.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4820333305528320.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4829535994380288.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4898217638494208.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4899524449402880.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4906481960878080.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4927372887326720.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4941019269300224.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4958903550869504.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/4996102363283456.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5053132042141696.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5100428188450816.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5101310674206720.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5120262028656640.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5150391945658368.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5154813513826304.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5188846583021568.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5195215432318976.png', 'https://s3-ap-northeast-1.amazonaws.com/projects.crowd4u.org/s201811523/qd/hat/5196434435 ...

# %%
print(len(url_list))
# Out:
# 303
